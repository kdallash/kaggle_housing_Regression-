# %% [markdown]
# ## Importing the required liberary

# %%
import pandas as pd
import numpy as np 

import seaborn as sns 
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Reading the data

# %%
# reading the data from its location in memory 
housingdf = pd.read_csv(r"C:\Users\Moga\final\train.csv") # change the location if you want to run cell 
# seeing the first n row of data 
housingdf.head(7)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ## Getting info about the data

# %%
# finding the number of rows and columns and nulls
housingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Describeing to find maens of numerical columns  
 
housingdf.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# ## converting the object columns to numerical to  be easier to use

# %%
# making a map for str to numbers 
map = {"Ex" :5,	
       "Gd":4,
       "TA":3,
       "Fa":2,
       "Po":1,
       "NA":0,
       "Av":5, 'Mn':3, 
       'No':0, "nan":0,
       'Y':1,'P':0.5,'N':0}

# %%
# using the map to replace the string with number 
housingdf.replace(map, inplace=True)
# Out:
# C:\Users\Moga\AppData\Local\Temp\ipykernel_18640\1062223066.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   housingdf.replace(map, inplace=True)

# %%
# Adding the similar category into one  
housingdf["Exter"] = housingdf["ExterQual"]+housingdf["ExterCond"]
housingdf["Bsmt"] = housingdf["BsmtCond"]+housingdf["BsmtQual"] +housingdf["BsmtExposure"]
# dropping unneeded category
housingdf.drop(labels=["ExterQual","ExterCond","BsmtCond","BsmtQual","BsmtExposure"],axis = 1,inplace = True)

# %%
# Finding the corrilation between the label and data
correlation_metrix =housingdf.corr(numeric_only=True)
correlation_metrix["SalePrice"].sort_values(ascending=False)
# look like extra and basmt have good correlation
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# KitchenQual      0.659600
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# Exter            0.589888
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# Bsmt             0.458653
# PoolQC           0.447936
# HeatingQC        0.427649
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# FireplaceQu      0.295794
# HalfBath         0.284108
# LotArea          0.263843
# CentralAir       0.251328
# PavedDrive       0.231357
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# GarageQual       0.156693
# GarageCond       0.125013
# ScreenPorch      0.111447
# ...

# %%
# making an array with the 20 index which have the highest correlation 
high_corr_index = correlation_metrix["SalePrice"].sort_values(ascending=False).index[0:20]

# %%
numerical_high_cor_housingdf = housingdf[high_corr_index]
numerical_high_cor_housingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     1460 non-null   int64
#  1   OverallQual   1460 non-null   int64
#  2   GrLivArea     1460 non-null   int64
#  3   KitchenQual   1460 non-null   int64
#  4   GarageCars    1460 non-null   int64
#  5   GarageArea    1460 non-null   int64
#  6   TotalBsmtSF   1460 non-null   int64
#  7   1stFlrSF      1460 non-null   int64
#  8   Exter         1460 non-null   int64
#  9   FullBath      1460 non-null   int64
#  10  TotRmsAbvGrd  1460 non-null   int64
#  11  YearBuilt     1460 non-null   int64
#  12  YearRemodAdd  1460 non-null   int64
#  13  GarageYrBlt   1379 non-null   float64
#  14  MasVnrArea    1452 non-null   float64
#  15  Fireplaces    1460 non-null   int64
#  16  Bsmt          1422 non-null   float64
#  17  PoolQC        7 non-null      float64
# ...

# %%
# drop useless columns 
numerical_high_cor_housingdf.drop(labels="PoolQC",axis=1,inplace=True)
# Out:
# C:\Users\Moga\AppData\Local\Temp\ipykernel_18640\3542661137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_high_cor_housingdf.drop(labels="PoolQC",axis=1,inplace=True)

# %% [markdown]
# ### calculate the skewness of the data

# %%
#plot the data to see if there is a skew  
numerical_high_cor_housingdf.hist(bins=50,figsize=(15,12))
plt.show()
# some data has a right skew like sale price amd TotalBsmtSF

# %%
y = numerical_high_cor_housingdf[["SalePrice"]]
x = numerical_high_cor_housingdf.drop(labels="SalePrice",axis=1)

# %%
from sklearn.model_selection import train_test_split
# splitting the data from label
y = numerical_high_cor_housingdf[["SalePrice"]]
X= numerical_high_cor_housingdf.drop(labels="SalePrice",axis=1)


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=24)

# %%
X_train
# Out:
#       OverallQual  GrLivArea  KitchenQual  GarageCars  GarageArea  \
# 1186            3       1699            3           2         420
# 952             5        768            3           1         396
# 842             6       1165            3           2         490
# 1410            7       1840            4           2         622
# 955             6       1958            3           2         492
# ...           ...        ...          ...         ...         ...
# 1425            6       1252            4           2         528
# 343             9       1684            5           2         564
# 192             7       1431            4           2         666
# 899             5       1236            3           1         288
# 418             5       1134            3           1         240
#
#       TotalBsmtSF  1stFlrSF  Exter  FullBath  TotRmsAbvGrd  YearBuilt  \
# 1186          978      1014      6         2             7       1900
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer 
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso,LogisticRegression,LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PowerTransformer,StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
# Define the pipeline structure
pipeline_template = [
    ("imputer", IterativeImputer()),
    ("scaler", StandardScaler()),
    ("correlator", PowerTransformer(method="yeo-johnson",standardize=False)),
    ("dimensionality_reduction", PCA(n_components=2)),
    ("model", None)  # Placeholder for the model
]

# %%
# Define models and their parameter grids
models = {
    "Linear Regression": (LinearRegression(), {
        "model__fit_intercept": [True, False],
    }),
    "Ridge Regression": (Ridge(), {
        "model__alpha": [0.1, 1.0, 10.0],
        "model__fit_intercept": [True, False],
    }),
    "Lasso Regression": (Lasso(), {
        "model__alpha": [0.1, 1.0, 10.0],
        "model__fit_intercept": [True, False],
    }),
    "Random Forest": (RandomForestRegressor(), {
        "model__n_estimators": [10, 50, 100],
        "model__max_depth": [None, 10, 20],
    }),
    "DecisionTreeRegressor":(DecisionTreeRegressor(),{
            'model__max_depth': [None, 3, 5,10],
    'model__splitter': ['best', 'random'],
    'model__max_features': ['sqrt', 'log2'],

    })
}

# %%
# Store results for comparison
results = {}
# Loop through models and perform grid search
for model_name, (model, param_grid) in models.items():
    # Create a new pipeline for each model
    pipeline = Pipeline(steps=pipeline_template)
    pipeline.set_params(model=model)  # Set the current model

    # Perform grid search
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring="r2")
    grid_search.fit(X_train, y_train.values.ravel())

    # Store the best scores for all metrics
    results[model_name] = grid_search.best_score_

# %%
# Print the comparison of results
print("Model Comparison:")
for model_name, scores in results.items():
    print(f"{model_name}  r2 score is {scores}")
# Out:
# Model Comparison:
# Linear Regression  r2 score is 0.7577874661244868
# Ridge Regression  r2 score is 0.7578581085987788
# Lasso Regression  r2 score is 0.7577900275302206
# Random Forest  r2 score is 0.825878291792858
# DecisionTreeRegressor  r2 score is 0.724087807077107

# %% [markdown]
# ## Fine toning the random forest model

# %%
param_grid = {
    'model__n_estimators': [100, 300, 500],
    'model__max_depth': [None, 10, 20, 30],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
}

# %%
pipeline_forest = Pipeline(steps=pipeline_template)
pipeline_forest.set_params(model=RandomForestRegressor())  # Set the model to the best model
# Out:
# Pipeline(steps=[('imputer', IterativeImputer()), ('scaler', StandardScaler()),
#                 ('corrilator', PowerTransformer(standardize=False)),
#                 ('dimensionality_reduction', PCA(n_components=2)),
#                 ('model', RandomForestRegressor())])

# %%
# Perform grid search
grid_search = GridSearchCV(pipeline_forest, param_grid, cv=5, scoring="r2")
grid_search.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('imputer', IterativeImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('corrilator',
#                                         PowerTransformer(standardize=False)),
#                                        ('dimensionality_reduction',
#                                         PCA(n_components=2)),
#                                        ('model', RandomForestRegressor())]),
#              param_grid={'model__max_depth': [None, 10, 20, 30],
#                          'model__min_samples_leaf': [1, 2, 4],
#                          'model__min_samples_split': [2, 5, 10],
#                          'model__n_estimators': [100, 300, 500]},
#              scoring='r2')

# %%
print(grid_search.best_score_)
best_forest = grid_search.best_estimator_
# Out:
# 0.8324231930287512

# %%
# importing the metrics 
from sklearn.metrics import r2_score,mean_absolute_error,max_error

# %%
def scoring(y_test,predect):
    r2 = r2_score(y_true=y_test,y_pred=predect)
    mean = mean_absolute_error(y_true=y_test,y_pred=predect)
    max = max_error(y_true=y_test,y_pred=predect)
    return(f"r2 score =  {r2},mean absolute error = {mean},max error = {mean}")

# %%
predict = best_forest.predict(X_test)
print(scoring(y_test=y_test,predect=predict))
# Out:
# r2 score =  0.8252576682381852,mean absolute error = 21355.329449622077,max error = 21355.329449622077

# %% [markdown]
# ## The model provide good result let's use it to predict housing price

# %%
# reading the data from its location in memory 
test_housing = pd.read_csv(r"C:\Users\Moga\final\test.csv") # change the location if you want to run cell

# %% [markdown]
# ## formatting the testing data

# %%
map = {"Ex" :5,	
       "Gd":4,
       "TA":3,
       "Fa":2,
       "Po":1,
       "NA":0,
       "Av":5, 'Mn':3, 
       'No':0, "nan":0,
       'Y':1,'P':0.5,'N':0}
# using the map to replace the string with number 
test_housing.replace(map, inplace=True)
# Adding the similar category into one  
test_housing["Exter"] = test_housing["ExterQual"]+test_housing["ExterCond"]
test_housing["Bsmt"] = test_housing["BsmtCond"]+test_housing["BsmtQual"] +test_housing["BsmtExposure"]
# dropping unneeded category
test_housing.drop(labels=["ExterQual","ExterCond","BsmtCond","BsmtQual","BsmtExposure"],axis = 1,inplace = True)
# Out:
# C:\Users\Moga\AppData\Local\Temp\ipykernel_18640\4127107160.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_housing.replace(map, inplace=True)

# %%
high_test_corr = list(high_corr_index)
high_test_corr.remove("SalePrice")
x_test_housing = test_housing[high_test_corr]
x_test_housing.drop(labels="PoolQC",axis=1,inplace=True)
# Out:
# C:\Users\Moga\AppData\Local\Temp\ipykernel_18640\1831909835.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test_housing.drop(labels="PoolQC",axis=1,inplace=True)

# %% [markdown]
# # predicting the test values

# %%
test_housing["SalePrice"] = best_forest.predict(x_test_housing)

# %%
result = test_housing[["Id","SalePrice"]]
result.to_csv("result.csv",index=False)
